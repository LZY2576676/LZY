# %% [markdown]
# ## Introduction
#
# The goal of this classification task is to predict the survival state of patients with liver cirrhosis during the course of the study.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import optuna
import shap

from lightgbm import LGBMClassifier
from sklearn.metrics import log_loss
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder

from pathlib import Path
from typing import Optional, List, Dict

plt.style.use('ggplot')
plt.rcParams.update({'figure.dpi':150})

# %%
train = pd.read_csv(data_path / 'train.csv', index_col=['id'])
test = pd.read_csv(data_path / 'test.csv', index_col=['id'])

train.head()
# Out:
#     N_Days             Drug    Age Sex Ascites Hepatomegaly Spiders Edema  \
# id
# 0      999  D-penicillamine  21532   M       N            N       N     N
# 1     2574          Placebo  19237   F       N            N       N     N
# 2     3428          Placebo  13727   F       N            Y       Y     Y
# 3     2576          Placebo  18460   F       N            N       N     N
# 4      788          Placebo  16658   F       N            Y       N     N
#
#     Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  Tryglicerides  \
# id
# 0         2.3        316.0     3.35   172.0    1601.0  179.80           63.0
# 1         0.9        364.0     3.54    63.0    1440.0  134.85           88.0
# 2         3.3        299.0     3.55   131.0    1029.0  119.35           50.0
# 3         0.6        256.0     3.50    58.0    1653.0   71.30           96.0
# 4         1.1        346.0     3.65    63.0    1181.0  125.55           96.0
#
#     Platelets  Prothrombin  Stage Status
# id
# 0       394.0          9.7    3.0      D
# 1       361.0         11.0    3.0      C
# 2       199.0         11.7    4.0      D
# 3       269.0         10.7    3.0      C
# 4       298.0         10.6    4.0      C

# %%
print(f'Number of observations in training data: {train.shape[0]}')
print(f'Number of columns in training data: {train.shape[1]}')
# Out:
# Number of observations in training data: 7905
# Number of columns in training data: 19

# %% [markdown]
# ## EDA
#
# We first check if there is any feature for which its mode has more than 90% of the observations. It is unlikely that any model can reliably use such features. So, we will drop them

# %%
from numbers import Number
def get_mode_fraction(x:pd.Series) -> float:
    cts = x.value_counts(sort=True, ascending=False)
    return cts.iloc[0]/x.shape[0]

def filter_greater_than(series:pd.Series,threshold:Number) -> pd.Series:
    '''
    Returns series elements greater than threshold. This funtion can be
    used with the .pipe methods
    '''
    return series[series>threshold]

high_mode_per = (
    train.drop('Status', axis=1)
    .apply(get_mode_fraction)
    .pipe(filter_greater_than, threshold = 0.9)
)
high_mode_per
# Out:
# Sex        0.928020
# Ascites    0.951929
# Edema      0.905882
# dtype: float64

# %%
# drop these columns
train = train.drop(high_mode_per.index.tolist(), axis=1)

# %% [markdown]
# We then check if any of the columns have any missing entries. There appear to be none.

# %%
# check for missing values
(
    train
    .isna()
    .sum()
    .pipe(filter_greater_than, 0)
)
# Out:
# Series([], dtype: int64)

# %% [markdown]
# We then inspect the training data. Apart from the target `Status`, there are 3 categorical-valued columns. The rest are all numerical.

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7905 entries, 0 to 7904
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   N_Days         7905 non-null   int64
#  1   Drug           7905 non-null   object
#  2   Age            7905 non-null   int64
#  3   Hepatomegaly   7905 non-null   object
#  4   Spiders        7905 non-null   object
#  5   Bilirubin      7905 non-null   float64
#  6   Cholesterol    7905 non-null   float64
#  7   Albumin        7905 non-null   float64
#  8   Copper         7905 non-null   float64
#  9   Alk_Phos       7905 non-null   float64
#  10  SGOT           7905 non-null   float64
#  11  Tryglicerides  7905 non-null   float64
#  12  Platelets      7905 non-null   float64
#  13  Prothrombin    7905 non-null   float64
#  14  Stage          7905 non-null   float64
#  15  Status         7905 non-null   object
# dtypes: float64(10), int64(2), object(4)
# memory usage: 1.0+ MB

# %% [markdown]
# ### Target
#
# The categorical target to predict is `Status`. There are three classes:
# - `C`: the patient was alive at `N_Days`
# - `CL`: the patient was alive at `N_Days` due to a liver transplant
# - `D`: the patient was deceased at `N_Days`,
#
# Here `N_Days` is the number of days between registration and the earlier of death, transplantation or the end of the study.
#
# There is quite a bit of class imbalance. In particular, there are very few observations for class `CL`. This makes sense as liver transplants are not too common.

# %%
# compute percentage of training observations per class
train['Status'].value_counts() / train.shape[0] * 100
# Out:
# Status
# C     62.808349
# D     33.712840
# CL     3.478811
# Name: count, dtype: float64

# %% [markdown]
# ### Categorical features
#
# There are 3 categorical features (after the initial preprocessing step), and all 3 are binary valued.

# %%
categorical_cols = []
for col in train.drop('Status', axis=1).columns:
    if train[col].dtype == 'object':
        categorical_cols.append(col)
        print(f"{col} has  {train[col].nunique()} unique values")
# Out:
# Drug has  2 unique values
# Hepatomegaly has  2 unique values
# Spiders has  2 unique values

# %% [markdown]
# Both categories of `Drug` and `Hepatomegaly` occur roughly in the same number of observations, while presence of `Spiders` (='Y') is far less common.

# %%
fig,axs = plt.subplots(1, len(categorical_cols), figsize=(4 * len(categorical_cols), 3))
for i in range(len(categorical_cols)):
    _ = sns.countplot(
        data=train, x=categorical_cols[i], ax=axs[i])
fig.tight_layout()

# %% [markdown]
# In the cell below, we plot the percentage of the class for each level of the 3 categorical features. Some observations:
#
# 1. Administering the drug is associated with slightly worse outcomes. It remains to be seen if this association is significant or not.
# 2. Presence of hepatomegaly is associated with much worse than outcomes than the absence.
# 3. Presence of spiders is associated with much worse than outcomes than the absence.

# %%
fig,axs = plt.subplots(1, len(categorical_cols), figsize=(3.5 * len(categorical_cols), 3), sharey=True)
for i in range(len(categorical_cols)):
    bars  = (
        train
        .groupby(categorical_cols[i])['Status']
        .value_counts(normalize=True)
        .mul(100)
        .rename('Percentage')
        .unstack()
        .fillna(0)
        .plot(kind='bar', stacked=False, rot=0, ax=axs[i])
    )
    
    for bar in bars.patches:
        yval = bar.get_height()
        axs[i].annotate(
            f'{yval:.1f}%', 
            (bar.get_x() + bar.get_width() / 2, yval),
            ha='center', va='bottom',
            fontsize=8
        )
    
    # titles
    _ = axs[i].set_ylabel('Percentage')
    if i > 0:
        _ = axs[i].get_legend().remove()
fig.tight_layout()

# %% [markdown]
# ### Numerical features
#
# We first plot the histograms of the numerical features to check for skewness. While this is not strictly needed for the tree-based models, the analysis might still be useful.
#
# From the plot, 'Bilirubin', 'Cholesterol', 'Copper', 'Alk_Phos', 'SGOT', 'Tryglicerides', 'Prothrombin' appear to have a large positive skew.

# %%
numerical_cols = train.select_dtypes(include='number').columns.tolist()

n_rows = 3
n_cols = 4
fig, axs = plt.subplots(n_rows, n_cols, figsize=(4 * n_cols, 3 * n_rows))
for i in range(n_rows):
    for j in range(n_cols):
        _ = sns.histplot(data=train, x=numerical_cols[n_cols * i + j], ax=axs[i, j], bins=15)

fig.tight_layout()

# %% [markdown]
# For these columns, we plot the boxplots with a log1p transform to check if there are any outliers. It turns out there are some outliers in the transformed variables.
#
# TODO: Handle outliers.

# %%
pos_skewed_cols = train[numerical_cols].skew().pipe(filter_greater_than, 1).index.tolist()

fig, axs = plt.subplots(1, len(pos_skewed_cols), figsize=(2 * len(pos_skewed_cols), 4))
for i, col in enumerate(pos_skewed_cols):
    _ = sns.boxplot(y = np.log1p(train[col]), ax=axs[i])
    _ = axs[i].set_ylabel(f'log1p_{col}')
fig.tight_layout()

# %% [markdown]
# Finally, we  plot the boxplots of ALL numerical features grouped by the different classes. There doesn't seem to be any significant pattern that sticks out. The models might benefit from some careful feature engineering.
#
# TODO: Feature engineering.

# %%
n_rows = 3
n_cols = 4
fig, axs = plt.subplots(n_rows, n_cols, figsize=(4 * n_cols, 3 * n_rows))
for i in range(n_rows):
    for j in range(n_cols):
        col = numerical_cols[n_cols * i + j]
        if col in pos_skewed_cols:
            _ = sns.boxplot(y=np.log1p(train[col]), x=train['Status'], ax=axs[i, j])
            _ = axs[i, j].set_ylabel(f'log1p_{col}')
        else:
            _ = sns.boxplot(data=train, y=col, x='Status', ax=axs[i, j])

fig.tight_layout()

# %% [markdown]
# ### Preparing the data

# %%
## convert binary columns to 0 or 1
pos_labels = {
    'Drug': 'D-penicillamine',
    'Hepatomegaly': 'Y',
    'Spiders': 'Y'
}

X = train.drop('Status', axis=1)
for col, pos_label in pos_labels.items():
    X[col] = 1 * (X[col] == pos_label)


# encode labels
le = LabelEncoder()
y = le.fit_transform(train['Status'])

# %% [markdown]
# ## Lightgbm model - training interface

# %%
def fit_model(
    X:pd.DataFrame,
    y:np.ndarray,
    config:Optional[Dict]=None,
    n_jobs:int=1
) -> LGBMClassifier:
    '''
    Train a lightgbm classifier on the data
    '''
    
    model = LGBMClassifier(
        n_jobs = n_jobs,
        importance_type='gain',
        subsample_freq=1
    )
    
    if config:
        # if config is supplied, set the model hyperparameters
        model.set_params(**config)
        
    return model.fit(X,y)

# %% [markdown]
# ## Tuning hyperparameters via Optuna

# %%
import joblib
# uncomment the following line to log only ERROR messages
# optuna.logging.set_verbosity(optuna.logging.ERROR)

def fit_and_test_fold(config:Dict,train_index,test_index) -> float:
    X_train = X.iloc[train_index,:]; X_test = X.iloc[test_index,:]
    y_train = y[train_index]; y_test = y[test_index]
    
    # fit model on training data
    model = fit_model(X_train,y_train,config,n_jobs=4)
    
    # generate predictions on test data
    test_pred_prob = model.predict_proba(X_test)
    
    return log_loss(y_test,test_pred_prob)

# loss function
def objective(trial):
    config = {
        'n_estimators':trial.suggest_int('n_estimators',50, 1500,log=True),
        'learning_rate': trial.suggest_float('learning_rate', 1e-5, 0.75,log=True),
        'num_leaves': trial.suggest_int('num_leaves', 2, 256, log=True),
        'colsample_bytree': trial.suggest_float("colsample_bytree", 0.1, 1),
        'colsample_bynode': trial.suggest_float("colsample_bynode", 0.1, 1),
        'subsample': trial.suggest_float("subsample", 0.1, 1),
        'min_child_samples':trial.suggest_int('min_child_samples',20, 200),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 100,log=True), # l1 regularization
        'reg_lambda': trial.suggest_float('reg_lambda',1e-8, 100, log=True), # l2 regularization
        'min_split_gain': trial.suggest_float('min_split_gain',1e-8,100, log=True), # gamma in xgboost,
    }
    
    
    # 4-fold cross-validation
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)
    
    cv_losses = [None]*5
    for i,(train_index, test_index) in enumerate(cv.split(X, y)):
        cv_losses[i] = fit_and_test_fold(config, train_index, test_index)
    
    return np.mean(cv_losses)

# the first `n_startup_trials` trials are drawn through random sampling
sampler = optuna.samplers.TPESampler(
    n_startup_trials=10,# recommended minimum: max(5,1+no_of_hyperparameters)
    seed=123
)

study = optuna.create_study(
    directions=['minimize'],sampler=sampler,study_name='lgbm'
)


study.optimize(objective, n_trials=100, timeout=1500) 
joblib.dump(study, "lgbm_survival.pkl") # save study for further runs
# Out:
# [I 2023-12-08 02:42:13,930] A new study created in memory with name: lgbm
# [I 2023-12-08 02:42:18,420] Trial 0 finished with value: 0.7219274636862434 and parameters: {'n_estimators': 533, 'learning_rate': 0.00024828288762242625, 'num_leaves': 5, 'colsample_bytree': 0.5961832921746021, 'colsample_bynode': 0.7475220728070068, 'subsample': 0.4807958141120149, 'min_child_samples': 197, 'reg_alpha': 0.07051757771805378, 'reg_lambda': 0.0006446426195647978, 'min_split_gain': 8.340175355380263e-05}. Best is trial 0 with value: 0.7219274636862434.
# [I 2023-12-08 02:42:20,221] Trial 1 finished with value: 0.4574996547403469 and parameters: {'n_estimators': 160, 'learning_rate': 0.03582300284516207, 'num_leaves': 14, 'colsample_bytree': 0.15371010694861154, 'colsample_bynode': 0.4582398297973883, 'subsample': 0.7641958651588321, 'min_child_samples': 53, 'reg_alpha': 5.682213681437011e-07, 'reg_lambda': 0.0020678247942007765, 'min_split_gain': 0.0020810181641723407}. Best is trial 1 with value: 0.4574996547403469.
# [I 2023-12-08 02:42:28,179] Trial 2 finished with value: 0.5988705688118874 and parameters: {'n_estimators': 431, 'learning_rate': 0.13836684398197868, 'num_leaves': 62, 'colsample_bytree': 0.6499211596098246, 'colsample_bynode': 0.7501990443131994, 'subsample': 0.39066302246786044, 'min_child_samples': 85, 'reg_alpha': 1.917045005848759e-06, 'reg_lambda': 8.652477206432139e-06, 'min_split_gain': 0.02040615769821286}. Best is trial 1 with value: 0.4574996547403469.
# [I 2023-12-08 02:42:28,979] Trial 3 finished with value: 0.7466471912090393 and parameters: {'n_estimators': 68, 'learning_rate': 0.0013011272927232168, 'num_leaves': 14, 'colsample_bytree': 0.5443165878852756, 'colsample_bynode': 0.4832472612662452, 'subsample': 0.38103510067521873, 'min_child_samples': 97, 'reg_alpha': 8.5879919993414, 'reg_lambda': 27.643955299436247, 'min_split_gain': 0.0010431980314094939}. Best is trial 1 with value: 0.4574996547403469.
# [I 2023-12-08 02:42:31,313] Trial 4 finished with value: 0.7716556401617273 and parameters: {'n_estimators': 416, 'learning_rate': 3.6613964758407626e-05, 'num_leaves': 8, 'colsample_bytree': 0.4733435907582686, 'colsample_bynode': 0.8796782420950293, 'subsample': 0.32540982885685604, 'min_child_samples': 107, 'reg_alpha': 71.71299425399306, 'reg_lambda': 0.0015662143278100168, 'min_split_gain': 0.013456907204414215}. Best is trial 1 with value: 0.4574996547403469.
# [I 2023-12-08 02:42:32,470] Trial 5 finished with value: 0.4516573151633899 and parameters: {'n_estimators': 75, 'learning_rate': 0.10677314300052246, 'num_leaves': 33, 'colsample_bytree': 0.5905612058198184, 'colsample_bynode': 0.4084874503968776, 'subsample': 0.3737087101244657, 'min_child_samples': 95, 'reg_alpha': 0.06501411542010016, 'reg_lambda': 5.6828791153785625, 'min_split_gain': 0.0012712277796716812}. Best is trial 5 with value: 0.4516573151633899.
# [I 2023-12-08 02:42:35,786] Trial 6 finished with value: 0.48037123547812294 and parameters: {'n_estimators': 486, 'learning_rate': 0.007185824235497023, 'num_leaves': 37, 'colsample_bytree': 0.7072201458890424, 'colsample_bynode': 0.8581081938582316, 'subsample': 0.1748754894991949, 'min_child_samples': 158, 'reg_alpha': 2.7331517507338647e-06, 'reg_lambda': 8.754464899604722e-07, 'min_split_gain': 0.005303585504099717}. Best is trial 5 with value: 0.4516573151633899.
# [I 2023-12-08 02:42:38,076] Trial 7 finished with value: 0.45077784534345894 and parameters: {'n_estimators': 69, 'learning_rate': 0.20702486790908275, 'num_leaves': 38, 'colsample_bytree': 0.7510747223709593, 'colsample_bynode': 0.11451628602551515, 'subsample': 0.6349886915005383, 'min_child_samples': 120, 'reg_alpha': 3.8868380129949447e-07, 'reg_lambda': 3.393947743751808e-07, 'min_split_gain': 0.09021843468757966}. Best is trial 7 with value: 0.45077784534345894.
# [I 2023-12-08 02:42:41,308] Trial 8 finished with value: 0.4488790034202824 and parameters: {'n_estimators': 147, 'learning_rate': 0.02362640167431321, 'num_leaves': 26, 'colsample_bytree': 0.4500555167108301, 'colsample_bynode': 0.9326192406525875, 'subsample': 0.8575029972214446, 'min_child_samples': 84, 'reg_alpha': 2.728441445955422e-08, 'reg_lambda': 1.1160425021379629e-05, 'min_split_gain': 9.590843826723352e-05}. Best is trial 8 with value: 0.4488790034202824.
# [I 2023-12-08 02:42:47,911] Trial 9 finished with value: 1.109312165242439 and parameters: {'n_estimators': 548, 'learning_rate': 0.7119239099485957, 'num_leaves': 9, 'colsample_bytree': 0.7862930324068904, 'colsample_bynode': 0.633859224905999, 'subsample': 0.7225316188301594, 'min_child_samples': 47, 'reg_alpha': 9.744575554640979e-05, 'reg_lambda': 2.561881144194724e-06, 'min_split_gain': 2.7199451141585286e-05}. Best is trial 8 with value: 0.4488790034202824.
# [I 2023-12-08 02:45:46,306] Trial 10 finished with value: 0.8495255679970996 and parameters: {'n_estimators': 1423, 'learning_rate': 0.010825769705055945, 'num_leaves': 223, 'colsample_bytree': 0.9345156271055195, 'colsample_bynode': 0.9892976403836156, 'subsample': 0.9718736866137505, 'min_child_samples': 20, 'reg_alpha': 5.215355511852748e-05, 'reg_lambda': 2.251383255193058e-08, 'min_split_gain': 2.7358527252845266e-08}. Best is trial 8 with value: 0.4488790034202824.
# [I 2023-12-08 02:45:46,893] Trial 11 finished with value: 0.8859216747303555 and parameters: {'n_estimators': 120, 'learning_rate': 0.49635784205884736, 'num_leaves': 3, 'colsample_bytree': 0.39355224151442036, 'colsample_bynode': 0.12657038219753564, 'subsample': 0.6515043067386491, 'min_child_samples': 143, 'reg_alpha': 1.4609181299936125e-08, 'reg_lambda': 4.116947619053891e-08, 'min_split_gain': 6.77412316903827}. Best is trial 8 with value: 0.4488790034202824.
# [I 2023-12-08 02:45:47,389] Trial 12 finished with value: 0.612047135492469 and parameters: {'n_estimators': 50, 'learning_rate': 0.025872924683806187, 'num_leaves': 2, 'colsample_bytree': 0.992276662278522, 'colsample_bynode': 0.10330987234502886, 'subsample': 0.8704428262919108, 'min_child_samples': 134, 'reg_alpha': 1.1854227098072202e-08, 'reg_lambda': 4.052113693827202e-06, 'min_split_gain': 1.6032179938705213}. Best is trial 8 with value: 0.4488790034202824.
# [I 2023-12-08 02:45:49,875] Trial 13 finished with value: 0.7213879033599682 and parameters: {'n_estimators': 158, 'learning_rate': 0.0018079089820152263, 'num_leaves': 66, 'colsample_bytree': 0.808090237481807, 'colsample_bynode': 0.3166204370755718, 'subsample': 0.6182638225477155, 'min_child_samples': 68, 'reg_alpha': 1.1578737813766142e-07, 'reg_lambda': 6.149780704290253e-05, 'min_split_gain': 58.388411887372584}. Best is trial 8 with value: 0.4488790034202824.
# [I 2023-12-08 02:45:52,071] Trial 14 finished with value: 0.44448008605689415 and parameters: {'n_estimators': 101, 'learning_rate': 0.09775829977131686, 'num_leaves': 27, 'colsample_bytree': 0.3795913035822128, 'colsample_bynode': 0.6062178289902873, 'subsample': 0.8385705072251549, 'min_child_samples': 132, 'reg_alpha': 3.1883720302856103e-07, 'reg_lambda': 2.1845471876465655e-07, 'min_split_gain': 0.2049278328077634}. Best is trial 14 with value: 0.44448008605689415.
# [I 2023-12-08 02:45:55,935] Trial 15 finished with value: 0.43964807351542534 and parameters: {'n_estimators': 215, 'learning_rate': 0.04005468312246169, 'num_leaves': 20, 'colsample_bytree': 0.33977512473526916, 'colsample_bynode': 0.6068316477735911, 'subsample': 0.9844825403341273, 'min_child_samples': 160, 'reg_alpha': 2.48158396521477e-05, 'reg_lambda': 6.606200706607026e-08, 'min_split_gain': 0.24185060935731023}. Best is trial 15 with value: 0.43964807351542534.
# [I 2023-12-08 02:45:58,762] Trial 16 finished with value: 0.437624606766437 and parameters: {'n_estimators': 239, 'learning_rate': 0.07367271661004596, 'num_leaves': 18, 'colsample_bytree': 0.298278394549783, 'colsample_bynode': 0.5975952167230943, 'subsample': 0.990278632865513, 'min_child_samples': 173, 'reg_alpha': 1.2086065431186772e-05, 'reg_lambda': 1.0053424289898466e-08, 'min_split_gain': 0.26888869971492924}. Best is trial 16 with value: 0.437624606766437.
# [I 2023-12-08 02:46:01,605] Trial 17 finished with value: 0.5523166322607963 and parameters: {'n_estimators': 240, 'learning_rate': 0.005134470973878417, 'num_leaves': 15, 'colsample_bytree': 0.25954037071762437, 'colsample_bynode': 0.5698231191599894, 'subsample': 0.9707222787079509, 'min_child_samples': 184, 'reg_alpha': 2.364443761521229e-05, 'reg_lambda': 1.8280675234838765e-08, 'min_split_gain': 1.452235572131947}. Best is trial 16 with value: 0.437624606766437.
# [I 2023-12-08 02:46:02,593] Trial 18 finished with value: 0.49934425737497834 and parameters: {'n_estimators': 230, 'learning_rate': 0.04534165459417032, 'num_leaves': 6, 'colsample_bytree': 0.2755721479205068, 'colsample_bynode': 0.687412732615595, 'subsample': 0.996226509786508, 'min_child_samples': 167, 'reg_alpha': 0.0009233740914076718, 'reg_lambda': 1.2985692801324264e-08, 'min_split_gain': 22.728448351656013}. Best is trial 16 with value: 0.437624606766437.
# [I 2023-12-08 02:46:04,043] Trial 19 finished with value: 0.4447203464447811 and parameters: {'n_estimators': 306, 'learning_rate': 0.3066210045133144, 'num_leaves': 4, 'colsample_bytree': 0.10273355764893233, 'colsample_bynode': 0.5481561170079573, 'subsample': 0.9002058903575165, 'min_child_samples': 170, 'reg_alpha': 8.339907341643069e-06, 'reg_lambda': 2.764515327587469e-07, 'min_split_gain': 0.5855647023590982}. Best is trial 16 with value: 0.437624606766437.
# [I 2023-12-08 02:46:05,213] Trial 20 finished with value: 0.5359068659680853 and parameters: {'n_estimators': 204, 'learning_rate': 0.06793509444506919, 'num_leaves': 9, 'colsample_bytree': 0.2552744136458179, 'colsample_bynode': 0.7083391301049273, 'subsample': 0.7731640268101014, 'min_child_samples': 200, 'reg_alpha': 0.00041124431320389165, 'reg_lambda': 1.2023400144298364e-07, 'min_split_gain': 4.074243902331297}. Best is trial 16 with value: 0.437624606766437.
# [I 2023-12-08 02:46:07,274] Trial 21 finished with value: 0.44606233384787164 and parameters: {'n_estimators': 109, 'learning_rate': 0.1262753172146573, 'num_leaves': 21, 'colsample_bytree': 0.349188907858254, 'colsample_bynode': 0.6270311298465282, 'subsample': 0.9028550215610149, 'min_child_samples': 146, 'reg_alpha': 6.600010745383834e-06, 'reg_lambda': 1.4954879268547705e-07, 'min_split_gain': 0.16322427247380483}. Best is trial 16 with value: 0.437624606766437.
# [I 2023-12-08 02:46:11,605] Trial 22 finished with value: 0.5214057910883215 and parameters: {'n_estimators': 311, 'learning_rate': 0.2625566870947536, 'num_leaves': 19, 'colsample_bytree': 0.36315664919880003, 'colsample_bynode': 0.5825548847983675, 'subsample': 0.8054771436540016, 'min_child_samples': 127, 'reg_alpha': 8.245161064092512e-07, 'reg_lambda': 1.1199799790111014e-08, 'min_split_gain': 0.16879254209285724}. Best is trial 16 with value: 0.437624606766437.
# [I 2023-12-08 02:46:13,139] Trial 23 finished with value: 0.4964038165797171 and parameters: {'n_estimators': 112, 'learning_rate': 0.015835333498187533, 'num_leaves': 12, 'colsample_bytree': 0.486020483857241, 'colsample_bynode': 0.7965763067554956, 'subsample': 0.9946546567862453, 'min_child_samples': 180, 'reg_alpha': 1.071982612511092e-07, 'reg_lambda': 1.3917703124755388e-07, 'min_split_gain': 0.07100231794440001}. Best is trial 16 with value: 0.437624606766437.
# [I 2023-12-08 02:46:14,160] Trial 24 finished with value: 0.6624890296772928 and parameters: {'n_estimators': 188, 'learning_rate': 0.06125226201883161, 'num_leaves': 22, 'colsample_bytree': 0.32851447784938836, 'colsample_bynode': 0.6578131150911467, 'subsample': 0.9117653261106987, 'min_child_samples': 153, 'reg_alpha': 1.1764967747163045e-05, 'reg_lambda': 6.053713208600674e-07, 'min_split_gain': 16.682835388366687}. Best is trial 16 with value: 0.437624606766437.
# [I 2023-12-08 02:46:16,131] Trial 25 finished with value: 0.43643624379526963 and parameters: {'n_estimators': 278, 'learning_rate': 0.08345372269587469, 'num_leaves': 52, 'colsample_bytree': 0.19701471782839974, 'colsample_bynode': 0.5538579773910133, 'subsample': 0.8374042365976437, 'min_child_samples': 178, 'reg_alpha': 0.00011149461264768245, 'reg_lambda': 7.193216297612885e-08, 'min_split_gain': 1.1385156815878312}. Best is trial 25 with value: 0.43643624379526963.
# [I 2023-12-08 02:46:21,349] Trial 26 finished with value: 0.455330331534904 and parameters: {'n_estimators': 292, 'learning_rate': 0.015805594123593964, 'num_leaves': 61, 'colsample_bytree': 0.1887675882939431, 'colsample_bynode': 0.5072040040288909, 'subsample': 0.9290506523969824, 'min_child_samples': 182, 'reg_alpha': 9.85361273896436e-05, 'reg_lambda': 6.352174288914577e-08, 'min_split_gain': 1.1158051824016193}. Best is trial 25 with value: 0.43643624379526963.
# [I 2023-12-08 02:46:22,658] Trial 27 finished with value: 0.6140524375379559 and parameters: {'n_estimators': 256, 'learning_rate': 0.041839974097020345, 'num_leaves': 104, 'colsample_bytree': 0.20075558892943793, 'colsample_bynode': 0.5411187320331985, 'subsample': 0.8163402459840938, 'min_child_samples': 166, 'reg_alpha': 0.0054001250360796015, 'reg_lambda': 1.4638332171777891e-08, 'min_split_gain': 8.583634845900894}. Best is trial 25 with value: 0.43643624379526963.
# [I 2023-12-08 02:46:23,425] Trial 28 finished with value: 1.4812012606870262 and parameters: {'n_estimators': 211, 'learning_rate': 0.37578056402974613, 'num_leaves': 42, 'colsample_bytree': 0.11769365381461032, 'colsample_bynode': 0.6636895171886582, 'subsample': 0.7241571545112949, 'min_child_samples': 195, 'reg_alpha': 3.0913262524493254e-05, 'reg_lambda': 1.2528538680224985e-06, 'min_split_gain': 81.37769484208926}. Best is trial 25 with value: 0.43643624379526963.
# [I 2023-12-08 02:46:24,870] Trial 29 finished with value: 0.4554846317785507 and parameters: {'n_estimators': 362, 'learning_rate': 0.6863149906883228, 'num_leaves': 18, 'colsample_bytree': 0.21896051820609505, 'colsample_bynode': 0.7465064552052296, 'subsample': 0.95086661199915, 'min_child_samples': 185, 'reg_alpha': 0.00030270169458847197, 'reg_lambda': 6.649336513412081e-08, 'min_split_gain': 1.0169528332828235}. Best is trial 25 with value: 0.43643624379526963.
# [I 2023-12-08 02:46:28,831] Trial 30 finished with value: 0.5218639673099402 and parameters: {'n_estimators': 362, 'learning_rate': 0.004881854097386629, 'num_leaves': 11, 'colsample_bytree': 0.2856556439571764, 'colsample_bynode': 0.41905743473011814, 'subsample': 0.864976225098668, 'min_child_samples': 160, 'reg_alpha': 0.001622294857649542, 'reg_lambda': 5.199255816965235e-05, 'min_split_gain': 0.02818664357355559}. Best is trial 25 with value: 0.43643624379526963.
# [I 2023-12-08 02:46:32,098] Trial 31 finished with value: 0.4456889396405315 and parameters: {'n_estimators': 191, 'learning_rate': 0.08510233178347891, 'num_leaves': 27, 'colsample_bytree': 0.37938168253367777, 'colsample_bynode': 0.604907712657442, 'subsample': 0.835385729229168, 'min_child_samples': 141, 'reg_alpha': 3.2988635784972635e-06, 'reg_lambda': 4.3007066703413116e-07, 'min_split_gain': 0.37066033510456226}. Best is trial 25 with value: 0.43643624379526963.
# [I 2023-12-08 02:46:34,341] Trial 32 finished with value: 0.4548470163333035 and parameters: {'n_estimators': 138, 'learning_rate': 0.1911474915312556, 'num_leaves': 27, 'colsample_bytree': 0.31445319563116186, 'colsample_bynode': 0.6194399591985713, 'subsample': 0.9226379600017409, 'min_child_samples': 172, 'reg_alpha': 9.082264653374172e-07, 'reg_lambda': 7.226845801235684e-08, 'min_split_gain': 0.24404162104792185}. Best is trial 25 with value: 0.43643624379526963.
# [I 2023-12-08 02:46:35,153] Trial 33 finished with value: 0.5133770819039059 and parameters: {'n_estimators': 88, 'learning_rate': 0.035988392948221246, 'num_leaves': 17, 'colsample_bytree': 0.16348614132396896, 'colsample_bynode': 0.5255231354443811, 'subsample': 0.7890016657130217, 'min_child_samples': 125, 'reg_alpha': 2.4739663506929563e-05, 'reg_lambda': 1.1225040563243064e-06, 'min_split_gain': 3.058873495458517}. Best is trial 25 with value: 0.43643624379526963.
# [I 2023-12-08 02:46:38,232] Trial 34 finished with value: 0.4691470887724116 and parameters: {'n_estimators': 171, 'learning_rate': 0.20550101482986496, 'num_leaves': 54, 'colsample_bytree': 0.22700258836278192, 'colsample_bynode': 0.6977005037061943, 'subsample': 0.8608638809017382, 'min_child_samples': 153, 'reg_alpha': 5.027983419967581e-06, 'reg_lambda': 1.9102418309304364e-07, 'min_split_gain': 0.030274986148408067}. Best is trial 25 with value: 0.43643624379526963.
# [I 2023-12-08 02:46:40,139] Trial 35 finished with value: 0.44278074836850634 and parameters: {'n_estimators': 133, 'learning_rate': 0.09660430205451521, 'num_leaves': 13, 'colsample_bytree': 0.41065299673806743, 'colsample_bynode': 0.4809003199160441, 'subsample': 0.9302296167502843, 'min_child_samples': 115, 'reg_alpha': 2.5422855079963886e-07, 'reg_lambda': 1.0903051328379175e-08, 'min_split_gain': 0.328498581724133}. Best is trial 25 with value: 0.43643624379526963.
# [I 2023-12-08 02:46:41,969] Trial 36 finished with value: 0.4431834346859625 and parameters: {'n_estimators': 142, 'learning_rate': 0.05897084930601529, 'num_leaves': 13, 'colsample_bytree': 0.4259522426684965, 'colsample_bynode': 0.4696781784403993, 'subsample': 0.9996278606918788, 'min_child_samples': 193, 'reg_alpha': 2.013656937738991e-06, 'reg_lambda': 1.0243936528209905e-08, 'min_split_gain': 0.007217685064513315}. Best is trial 25 with value: 0.43643624379526963.
# [I 2023-12-08 02:46:43,531] Trial 37 finished with value: 0.44253644649736845 and parameters: {'n_estimators': 168, 'learning_rate': 0.1160796664367231, 'num_leaves': 6, 'colsample_bytree': 0.3110997566969895, 'colsample_bynode': 0.4900418906831488, 'subsample': 0.936557184937795, 'min_child_samples': 175, 'reg_alpha': 1.532249265285598e-06, 'reg_lambda': 4.5025674061602884e-08, 'min_split_gain': 0.052321204065936655}. Best is trial 25 with value: 0.43643624379526963.
# [I 2023-12-08 02:46:45,127] Trial 38 finished with value: 0.7358431413476065 and parameters: {'n_estimators': 168, 'learning_rate': 0.0007087049817686388, 'num_leaves': 6, 'colsample_bytree': 0.30239470709168154, 'colsample_bynode': 0.4343604215161983, 'subsample': 0.9318368247492724, 'min_child_samples': 176, 'reg_alpha': 6.754253003696728e-05, 'reg_lambda': 4.1845717475021446e-08, 'min_split_gain': 0.014925198278737313}. Best is trial 25 with value: 0.43643624379526963.
# [I 2023-12-08 02:46:46,998] Trial 39 finished with value: 0.4379856494823057 and parameters: {'n_estimators': 257, 'learning_rate': 0.13996579822809835, 'num_leaves': 7, 'colsample_bytree': 0.15276639459136987, 'colsample_bynode': 0.520688979660087, 'subsample': 0.9574298399771405, 'min_child_samples': 190, 'reg_alpha': 2.55906469570866e-06, 'reg_lambda': 9.741376302415015e-06, 'min_split_gain': 0.056284356609627176}. Best is trial 25 with value: 0.43643624379526963.
# [I 2023-12-08 02:46:49,339] Trial 40 finished with value: 0.4593828344463904 and parameters: {'n_estimators': 246, 'learning_rate': 0.027833454689399923, 'num_leaves': 11, 'colsample_bytree': 0.14867423368214575, 'colsample_bynode': 0.5633181853729733, 'subsample': 0.7475826106892122, 'min_child_samples': 191, 'reg_alpha': 1.5494535024064865e-05, 'reg_lambda': 9.670013529610164e-06, 'min_split_gain': 0.004302539749699108}. Best is trial 25 with value: 0.43643624379526963.
# [I 2023-12-08 02:46:52,445] Trial 41 finished with value: 0.4388010719794274 and parameters: {'n_estimators': 211, 'learning_rate': 0.14407921590931771, 'num_leaves': 7, 'colsample_bytree': 0.22640937995740867, 'colsample_bynode': 0.5072870273785366, 'subsample': 0.9578056265207788, 'min_child_samples': 161, 'reg_alpha': 1.685854017223941e-06, 'reg_lambda': 4.2424374062566343e-08, 'min_split_gain': 0.03834293714778647}. Best is trial 25 with value: 0.43643624379526963.
# [I 2023-12-08 02:46:54,717] Trial 42 finished with value: 0.4405236384182155 and parameters: {'n_estimators': 270, 'learning_rate': 0.16494624930229007, 'num_leaves': 7, 'colsample_bytree': 0.18916190850985792, 'colsample_bynode': 0.5254855398639523, 'subsample': 0.8889307447929267, 'min_child_samples': 163, 'reg_alpha': 4.4952827734189595e-06, 'reg_lambda': 1.0118530107644369e-06, 'min_split_gain': 0.06975999849091792}. Best is trial 25 with value: 0.43643624379526963.
# [I 2023-12-08 02:46:55,868] Trial 43 finished with value: 0.4496478779363319 and parameters: {'n_estimators': 230, 'learning_rate': 0.45304010825125207, 'num_leaves': 8, 'colsample_bytree': 0.23551357765367825, 'colsample_bynode': 0.5765261907220799, 'subsample': 0.9628434967906934, 'min_child_samples': 153, 'reg_alpha': 1.3249237333987514e-06, 'reg_lambda': 4.6498789176302804e-07, 'min_split_gain': 0.5783796372944577}. Best is trial 25 with value: 0.43643624379526963.
# [I 2023-12-08 02:46:57,163] Trial 44 finished with value: 0.445248244135788 and parameters: {'n_estimators': 219, 'learning_rate': 0.2891144816401799, 'num_leaves': 4, 'colsample_bytree': 0.16226389777979136, 'colsample_bynode': 0.3954081174715116, 'subsample': 0.9976504575824218, 'min_child_samples': 188, 'reg_alpha': 9.504353260157174e-05, 'reg_lambda': 2.021044066761263e-06, 'min_split_gain': 0.013591561547686351}. Best is trial 25 with value: 0.43643624379526963.
# [I 2023-12-08 02:47:00,537] Trial 45 finished with value: 0.4618810288292206 and parameters: {'n_estimators': 341, 'learning_rate': 0.16898785905229236, 'num_leaves': 9, 'colsample_bytree': 0.2603437844162868, 'colsample_bynode': 0.6317529863034475, 'subsample': 0.8784818717432037, 'min_child_samples': 200, 'reg_alpha': 8.550370939740923e-06, 'reg_lambda': 4.702430350033913e-06, 'min_split_gain': 0.0015716632998699798}. Best is trial 25 with value: 0.43643624379526963.
# [I 2023-12-08 02:47:02,587] Trial 46 finished with value: 0.4489915177402503 and parameters: {'n_estimators': 433, 'learning_rate': 0.0629246037722386, 'num_leaves': 15, 'colsample_bytree': 0.13001810068091954, 'colsample_bynode': 0.4527996068833514, 'subsample': 0.9562982562829274, 'min_child_samples': 160, 'reg_alpha': 2.6896430055468954e-06, 'reg_lambda': 3.330953614581987e-08, 'min_split_gain': 2.504009746583981}. Best is trial 25 with value: 0.43643624379526963.
# [I 2023-12-08 02:47:05,475] Trial 47 finished with value: 0.45417972751771896 and parameters: {'n_estimators': 274, 'learning_rate': 0.018658616767091317, 'num_leaves': 10, 'colsample_bytree': 0.19221502612305053, 'colsample_bynode': 0.5069245946518494, 'subsample': 0.8479422951501975, 'min_child_samples': 101, 'reg_alpha': 3.8179414810769814e-05, 'reg_lambda': 1.1255837409430522e-07, 'min_split_gain': 0.08185972587140691}. Best is trial 25 with value: 0.43643624379526963.
# [I 2023-12-08 02:47:09,281] Trial 48 finished with value: 0.43771401138835425 and parameters: {'n_estimators': 196, 'learning_rate': 0.03486766496135552, 'num_leaves': 34, 'colsample_bytree': 0.22992235443556955, 'colsample_bynode': 0.5931557228413992, 'subsample': 0.8135386970781696, 'min_child_samples': 139, 'reg_alpha': 0.0001805324910209299, 'reg_lambda': 4.156420408052848e-07, 'min_split_gain': 0.00045992003253740794}. Best is trial 25 with value: 0.43643624379526963.
# [I 2023-12-08 02:47:12,081] Trial 49 finished with value: 0.4397850075827624 and parameters: {'n_estimators': 193, 'learning_rate': 0.13623258830473584, 'num_leaves': 36, 'colsample_bytree': 0.10124392750362789, 'colsample_bynode': 0.3905634459375392, 'subsample': 0.8069937190087314, 'min_child_samples': 142, 'reg_alpha': 0.0001829430571070728, 'reg_lambda': 5.015558753120907e-07, 'min_split_gain': 0.0005888255459183038}. Best is trial 25 with value: 0.43643624379526963.
# [I 2023-12-08 02:47:19,669] Trial 50 finished with value: 0.4307515574345562 and parameters: {'n_estimators': 537, 'learning_rate': 0.025739300811361793, 'num_leaves': 31, 'colsample_bytree': 0.15900540747159314, 'colsample_bynode': 0.5669199185002946, 'subsample': 0.773024984815089, 'min_child_samples': 136, 'reg_alpha': 0.00021016241119638994, 'reg_lambda': 2.5407134070117027e-06, 'min_split_gain': 0.004157251969567357}. Best is trial 50 with value: 0.4307515574345562.
# [I 2023-12-08 02:47:27,607] Trial 51 finished with value: 0.4643870431416537 and parameters: {'n_estimators': 486, 'learning_rate': 0.00984575039620921, 'num_leaves': 44, 'colsample_bytree': 0.14855570685701663, 'colsample_bynode': 0.5487477671064201, 'subsample': 0.7399553176785864, 'min_child_samples': 133, 'reg_alpha': 0.00018209640021514515, 'reg_lambda': 2.605682110498436e-06, 'min_split_gain': 0.0005270234434431246}. Best is trial 50 with value: 0.4307515574345562.
# [I 2023-12-08 02:47:40,417] Trial 52 finished with value: 0.4368052844761866 and parameters: {'n_estimators': 721, 'learning_rate': 0.027623817119094136, 'num_leaves': 31, 'colsample_bytree': 0.2303678051321444, 'colsample_bynode': 0.5801646478905356, 'subsample': 0.7680759612631879, 'min_child_samples': 147, 'reg_alpha': 5.4321676558275404e-05, 'reg_lambda': 1.6346331271146862e-05, 'min_split_gain': 0.002065375243371106}. Best is trial 50 with value: 0.4307515574345562.
# [I 2023-12-08 02:47:52,351] Trial 53 finished with value: 0.4440237892286552 and parameters: {'n_estimators': 626, 'learning_rate': 0.02837732534733437, 'num_leaves': 32, 'colsample_bytree': 0.265109505198463, 'colsample_bynode': 0.5874845551714981, 'subsample': 0.7735190522933805, 'min_child_samples': 117, 'reg_alpha': 0.0006854524583153257, 'reg_lambda': 2.1629763514308315e-05, 'min_split_gain': 0.003199064929566249}. Best is trial 50 with value: 0.4307515574345562.
# [I 2023-12-08 02:48:05,038] Trial 54 finished with value: 0.45736680822807035 and parameters: {'n_estimators': 677, 'learning_rate': 0.04584615370166896, 'num_leaves': 23, 'colsample_bytree': 0.183200612113827, 'colsample_bynode': 0.5606589978922459, 'subsample': 0.6930409983631002, 'min_child_samples': 107, 'reg_alpha': 0.0018753227682494489, 'reg_lambda': 0.00018631036494462164, 'min_split_gain': 0.00022190072647178196}. Best is trial 50 with value: 0.4307515574345562.
# [I 2023-12-08 02:48:21,316] Trial 55 finished with value: 0.43782780126177634 and parameters: {'n_estimators': 788, 'learning_rate': 0.020461781017783738, 'num_leaves': 31, 'colsample_bytree': 0.22053456676256333, 'colsample_bynode': 0.6523928282982805, 'subsample': 0.8265820832292612, 'min_child_samples': 89, 'reg_alpha': 6.984669817437629e-05, 'reg_lambda': 7.514418193947193e-06, 'min_split_gain': 0.008766875385580165}. Best is trial 50 with value: 0.4307515574345562.
# [I 2023-12-08 02:48:37,698] Trial 56 finished with value: 0.4388955265280762 and parameters: {'n_estimators': 734, 'learning_rate': 0.0117080774125403, 'num_leaves': 32, 'colsample_bytree': 0.29169894545406216, 'colsample_bynode': 0.6542556058224449, 'subsample': 0.6959572226524849, 'min_child_samples': 75, 'reg_alpha': 5.231410637217617e-05, 'reg_lambda': 3.6719629754438895e-06, 'min_split_gain': 0.0018961415396221472}. Best is trial 50 with value: 0.4307515574345562.
# [I 2023-12-08 02:48:57,391] Trial 57 finished with value: 0.4430129034192271 and parameters: {'n_estimators': 869, 'learning_rate': 0.021586112168071193, 'num_leaves': 49, 'colsample_bytree': 0.23193463915956009, 'colsample_bynode': 0.6701585446631476, 'subsample': 0.7724807573252397, 'min_child_samples': 94, 'reg_alpha': 0.0001853316937642362, 'reg_lambda': 2.1240443566063857e-05, 'min_split_gain': 0.008416088767769399}. Best is trial 50 with value: 0.4307515574345562.
# [I 2023-12-08 02:49:26,074] Trial 58 finished with value: 0.5164788422446766 and parameters: {'n_estimators': 964, 'learning_rate': 0.02942952621260551, 'num_leaves': 37, 'colsample_bytree': 0.349668424172063, 'colsample_bynode': 0.7167978015349097, 'subsample': 0.8231964954544939, 'min_child_samples': 72, 'reg_alpha': 1.7753520852737887e-05, 'reg_lambda': 3.216044419389567e-07, 'min_split_gain': 4.1557033555697746e-05}. Best is trial 50 with value: 0.4307515574345562.
# [I 2023-12-08 02:49:38,414] Trial 59 finished with value: 0.4545429270717471 and parameters: {'n_estimators': 569, 'learning_rate': 0.008168199132057453, 'num_leaves': 71, 'colsample_bytree': 0.2505553711750224, 'colsample_bynode': 0.6036503871017451, 'subsample': 0.5817788589961452, 'min_child_samples': 88, 'reg_alpha': 0.0004954391830676778, 'reg_lambda': 5.822753888718452e-06, 'min_split_gain': 0.003650407995911028}. Best is trial 50 with value: 0.4307515574345562.
# [I 2023-12-08 02:49:46,334] Trial 60 finished with value: 0.44014759328285613 and parameters: {'n_estimators': 463, 'learning_rate': 0.013555244370043983, 'num_leaves': 24, 'colsample_bytree': 0.20893051916423505, 'colsample_bynode': 0.642017395943938, 'subsample': 0.7972638797768369, 'min_child_samples': 147, 'reg_alpha': 0.004999005469672251, 'reg_lambda': 1.6374535434466215e-06, 'min_split_gain': 0.000945189736641438}. Best is trial 50 with value: 0.4307515574345562.
# [I 2023-12-08 02:49:53,153] Trial 61 finished with value: 0.44966628337117587 and parameters: {'n_estimators': 401, 'learning_rate': 0.07953337938305, 'num_leaves': 32, 'colsample_bytree': 0.13083729336427363, 'colsample_bynode': 0.586788238840913, 'subsample': 0.8850246370838649, 'min_child_samples': 61, 'reg_alpha': 5.888082364285249e-05, 'reg_lambda': 1.011650906648241e-05, 'min_split_gain': 0.009488123522666798}. Best is trial 50 with value: 0.4307515574345562.
# [I 2023-12-08 02:49:58,335] Trial 62 finished with value: 0.43920719438128125 and parameters: {'n_estimators': 272, 'learning_rate': 0.021496917372869864, 'num_leaves': 28, 'colsample_bytree': 0.16845607600755802, 'colsample_bynode': 0.6287935913503513, 'subsample': 0.8443182348353275, 'min_child_samples': 122, 'reg_alpha': 1.5958682125569966e-05, 'reg_lambda': 0.0007910539853380861, 'min_split_gain': 0.022343865356457174}. Best is trial 50 with value: 0.4307515574345562.
# [I 2023-12-08 02:50:06,070] Trial 63 finished with value: 0.43375589029075223 and parameters: {'n_estimators': 536, 'learning_rate': 0.05111461220447348, 'num_leaves': 20, 'colsample_bytree': 0.132896096828771, 'colsample_bynode': 0.5539712662854291, 'subsample': 0.8971754859949569, 'min_child_samples': 42, 'reg_alpha': 0.00011955751144394044, 'reg_lambda': 8.993804078240655e-07, 'min_split_gain': 0.12969399582923277}. Best is trial 50 with value: 0.4307515574345562.
# [I 2023-12-08 02:50:14,289] Trial 64 finished with value: 0.44373991107706046 and parameters: {'n_estimators': 526, 'learning_rate': 0.048339391753131705, 'num_leaves': 20, 'colsample_bytree': 0.20079446032759005, 'colsample_bynode': 0.5775202269166595, 'subsample': 0.8237241386240367, 'min_child_samples': 41, 'reg_alpha': 0.00012911949386591525, 'reg_lambda': 7.912000782656347e-07, 'min_split_gain': 0.10601215358698038}. Best is trial 50 with value: 0.4307515574345562.
# [I 2023-12-08 02:50:18,156] Trial 65 finished with value: 0.4310686118592207 and parameters: {'n_estimators': 320, 'learning_rate': 0.04060062787492053, 'num_leaves': 17, 'colsample_bytree': 0.1291249608758438, 'colsample_bynode': 0.6796507459982691, 'subsample': 0.9045281045050944, 'min_child_samples': 23, 'reg_alpha': 0.000408516859201868, 'reg_lambda': 2.69121195705174e-07, 'min_split_gain': 0.004176864373061794}. Best is trial 50 with value: 0.4307515574345562.
# [I 2023-12-08 02:50:22,236] Trial 66 finished with value: 0.4315116000336351 and parameters: {'n_estimators': 328, 'learning_rate': 0.0773093395491399, 'num_leaves': 17, 'colsample_bytree': 0.11369248530935647, 'colsample_bynode': 0.6792650337106682, 'subsample': 0.8933781491907935, 'min_child_samples': 20, 'reg_alpha': 0.0002816232939387836, 'reg_lambda': 2.1313524672196967e-07, 'min_split_gain': 0.0023254188375284313}. Best is trial 50 with value: 0.4307515574345562.
# [I 2023-12-08 02:50:25,861] Trial 67 finished with value: 0.4313818333021411 and parameters: {'n_estimators': 315, 'learning_rate': 0.07611506805698476, 'num_leaves': 16, 'colsample_bytree': 0.13927040362825863, 'colsample_bynode': 0.6846105763911519, 'subsample': 0.9097651690464718, 'min_child_samples': 41, 'reg_alpha': 0.00036521755578643595, 'reg_lambda': 1.2456796791781194e-07, 'min_split_gain': 0.0026575156944903997}. Best is trial 50 with value: 0.4307515574345562.
# [I 2023-12-08 02:50:29,815] Trial 68 finished with value: 0.43603916724680547 and parameters: {'n_estimators': 320, 'learning_rate': 0.09465887705247948, 'num_leaves': 17, 'colsample_bytree': 0.10249573194396436, 'colsample_bynode': 0.741579377448721, 'subsample': 0.9031726517923387, 'min_child_samples': 22, 'reg_alpha': 0.0003383720259678055, 'reg_lambda': 2.0214655318271285e-07, 'min_split_gain': 0.0024119657243934813}. Best is trial 50 with value: 0.4307515574345562.
# [I 2023-12-08 02:50:35,140] Trial 69 finished with value: 0.4520804056606876 and parameters: {'n_estimators': 325, 'learning_rate': 0.10435749599502323, 'num_leaves': 16, 'colsample_bytree': 0.10406503268631509, 'colsample_bynode': 0.7821302055775305, 'subsample': 0.8783345812798782, 'min_child_samples': 24, 'reg_alpha': 0.00034280002825349355, 'reg_lambda': 1.9672886249748407e-07, 'min_split_gain': 0.003611580910720453}. Best is trial 50 with value: 0.4307515574345562.
# [I 2023-12-08 02:50:39,691] Trial 70 finished with value: 0.43063033037170884 and parameters: {'n_estimators': 404, 'learning_rate': 0.0573163687966899, 'num_leaves': 15, 'colsample_bytree': 0.12990442246544506, 'colsample_bynode': 0.7334848086828064, 'subsample': 0.9078361626185426, 'min_child_samples': 30, 'reg_alpha': 0.0008723309208042224, 'reg_lambda': 2.5352531205321562e-08, 'min_split_gain': 0.0002023065932309375}. Best is trial 70 with value: 0.43063033037170884.
# [I 2023-12-08 02:50:43,941] Trial 71 finished with value: 0.43509162336777163 and parameters: {'n_estimators': 391, 'learning_rate': 0.08155463181129316, 'num_leaves': 15, 'colsample_bytree': 0.13029466643475685, 'colsample_bynode': 0.7321669583805338, 'subsample': 0.9059656324856484, 'min_child_samples': 30, 'reg_alpha': 0.0012256913643749767, 'reg_lambda': 2.3959547590936207e-08, 'min_split_gain': 0.0011234353598232767}. Best is trial 70 with value: 0.43063033037170884.
# [I 2023-12-08 02:50:48,341] Trial 72 finished with value: 0.42973232538317446 and parameters: {'n_estimators': 399, 'learning_rate': 0.053122667702854495, 'num_leaves': 15, 'colsample_bytree': 0.12371516300967399, 'colsample_bynode': 0.7268795660225219, 'subsample': 0.9040871841382698, 'min_child_samples': 31, 'reg_alpha': 0.0009016533864149714, 'reg_lambda': 2.439992511906211e-08, 'min_split_gain': 0.00016682027286987587}. Best is trial 72 with value: 0.42973232538317446.
# [I 2023-12-08 02:50:52,833] Trial 73 finished with value: 0.42893390685423105 and parameters: {'n_estimators': 406, 'learning_rate': 0.052085579448272856, 'num_leaves': 14, 'colsample_bytree': 0.13731565734852944, 'colsample_bynode': 0.7165185614997585, 'subsample': 0.910975281948418, 'min_child_samples': 31, 'reg_alpha': 0.001109975144779544, 'reg_lambda': 2.4427896630712937e-08, 'min_split_gain': 0.00020483660175953246}. Best is trial 73 with value: 0.42893390685423105.
# [I 2023-12-08 02:50:56,888] Trial 74 finished with value: 0.42759112205566135 and parameters: {'n_estimators': 368, 'learning_rate': 0.05577048105450716, 'num_leaves': 14, 'colsample_bytree': 0.13770461423911853, 'colsample_bynode': 0.6909057475464165, 'subsample': 0.8587097174515578, 'min_child_samples': 37, 'reg_alpha': 0.000768987964576533, 'reg_lambda': 2.3832567752744214e-08, 'min_split_gain': 7.268722650985858e-05}. Best is trial 74 with value: 0.42759112205566135.
# [I 2023-12-08 02:51:01,501] Trial 75 finished with value: 0.4360538057331852 and parameters: {'n_estimators': 383, 'learning_rate': 0.061045921666674156, 'num_leaves': 13, 'colsample_bytree': 0.1704265746720334, 'colsample_bynode': 0.6841119220339055, 'subsample': 0.8621048002732392, 'min_child_samples': 32, 'reg_alpha': 0.003047033052605364, 'reg_lambda': 2.5587195959840513e-08, 'min_split_gain': 0.0001564204560290848}. Best is trial 74 with value: 0.42759112205566135.
# [I 2023-12-08 02:51:07,072] Trial 76 finished with value: 0.4319415435938031 and parameters: {'n_estimators': 436, 'learning_rate': 0.036068063403973276, 'num_leaves': 12, 'colsample_bytree': 0.14509160162872606, 'colsample_bynode': 0.7076309280356947, 'subsample': 0.9272885466269256, 'min_child_samples': 33, 'reg_alpha': 0.0008616992565999003, 'reg_lambda': 1.0644676205543457e-07, 'min_split_gain': 6.256007339905868e-05}. Best is trial 74 with value: 0.42759112205566135.
# [I 2023-12-08 02:51:11,049] Trial 77 finished with value: 0.5222144764156613 and parameters: {'n_estimators': 351, 'learning_rate': 0.24760937710558245, 'num_leaves': 14, 'colsample_bytree': 0.1270849324920529, 'colsample_bynode': 0.7863763607368428, 'subsample': 0.8586666617049573, 'min_child_samples': 54, 'reg_alpha': 0.006591171488668636, 'reg_lambda': 2.0595490100500837e-08, 'min_split_gain': 2.6769090123097388e-05}. Best is trial 74 with value: 0.42759112205566135.
# [I 2023-12-08 02:51:15,411] Trial 78 finished with value: 0.4309482411404587 and parameters: {'n_estimators': 299, 'learning_rate': 0.049005664932717484, 'num_leaves': 17, 'colsample_bytree': 0.17097671594751918, 'colsample_bynode': 0.6771492177692429, 'subsample': 0.9138110195807556, 'min_child_samples': 39, 'reg_alpha': 0.0007371484346031895, 'reg_lambda': 7.470045811228995e-08, 'min_split_gain': 0.00014201940952963455}. Best is trial 74 with value: 0.42759112205566135.
# [I 2023-12-08 02:51:21,797] Trial 79 finished with value: 0.43867202056943844 and parameters: {'n_estimators': 414, 'learning_rate': 0.05375182827250162, 'num_leaves': 19, 'colsample_bytree': 0.17231586942965638, 'colsample_bynode': 0.7735001863211121, 'subsample': 0.9417522187468679, 'min_child_samples': 38, 'reg_alpha': 0.0007549927838217201, 'reg_lambda': 9.21257539077097e-08, 'min_split_gain': 2.2063043411005824e-05}. Best is trial 74 with value: 0.42759112205566135.
# [I 2023-12-08 02:51:26,194] Trial 80 finished with value: 0.43577186523266187 and parameters: {'n_estimators': 295, 'learning_rate': 0.03498688328481129, 'num_leaves': 22, 'colsample_bytree': 0.14855548618714415, 'colsample_bynode': 0.8197013508728452, 'subsample': 0.9731084684667208, 'min_child_samples': 47, 'reg_alpha': 0.002028083695768439, 'reg_lambda': 2.1586152801704764e-08, 'min_split_gain': 0.00012311872542233025}. Best is trial 74 with value: 0.42759112205566135.
# [I 2023-12-08 02:51:30,809] Trial 81 finished with value: 0.43157291806804265 and parameters: {'n_estimators': 369, 'learning_rate': 0.06822723552420112, 'num_leaves': 17, 'colsample_bytree': 0.11395054106380058, 'colsample_bynode': 0.6826348691287106, 'subsample': 0.9123180184124662, 'min_child_samples': 30, 'reg_alpha': 0.0006213817416906624, 'reg_lambda': 5.019468015533854e-08, 'min_split_gain': 0.00023258798124193075}. Best is trial 74 with value: 0.42759112205566135.
# [I 2023-12-08 02:51:35,205] Trial 82 finished with value: 0.4313782721328627 and parameters: {'n_estimators': 343, 'learning_rate': 0.04515911142860112, 'num_leaves': 15, 'colsample_bytree': 0.17413603982074813, 'colsample_bynode': 0.7152283024461846, 'subsample': 0.8754828506473725, 'min_child_samples': 27, 'reg_alpha': 0.0004337293054454106, 'reg_lambda': 2.363427714565511e-07, 'min_split_gain': 0.00027983918245332495}. Best is trial 74 with value: 0.42759112205566135.
# [I 2023-12-08 02:51:40,451] Trial 83 finished with value: 0.4532782911392612 and parameters: {'n_estimators': 301, 'learning_rate': 0.01451933609508742, 'num_leaves': 14, 'colsample_bytree': 0.17952193004399156, 'colsample_bynode': 0.722376476742175, 'subsample': 0.8716213681120866, 'min_child_samples': 26, 'reg_alpha': 0.0032722880550052446, 'reg_lambda': 7.693245613133492e-08, 'min_split_gain': 7.402767139635468e-05}. Best is trial 74 with value: 0.42759112205566135.
# [I 2023-12-08 02:51:44,748] Trial 84 finished with value: 0.4535046012636116 and parameters: {'n_estimators': 451, 'learning_rate': 0.11528271369690933, 'num_leaves': 11, 'colsample_bytree': 0.16317598828470845, 'colsample_bynode': 0.7550788603038648, 'subsample': 0.9192787449377618, 'min_child_samples': 49, 'reg_alpha': 0.0012349641254805247, 'reg_lambda': 3.6981972174968536e-08, 'min_split_gain': 0.00030856378108146023}. Best is trial 74 with value: 0.42759112205566135.
# [I 2023-12-08 02:51:49,641] Trial 85 finished with value: 0.4364088129444504 and parameters: {'n_estimators': 368, 'learning_rate': 0.05373877262055867, 'num_leaves': 15, 'colsample_bytree': 0.19341946086578715, 'colsample_bynode': 0.7119613361027234, 'subsample': 0.9443026236830426, 'min_child_samples': 36, 'reg_alpha': 0.0004482187237249898, 'reg_lambda': 1.639308970741422e-08, 'min_split_gain': 0.00014880583114628695}. Best is trial 74 with value: 0.42759112205566135.
# [I 2023-12-08 02:51:55,511] Trial 86 finished with value: 0.42683703811949225 and parameters: {'n_estimators': 401, 'learning_rate': 0.04229700512541299, 'num_leaves': 24, 'colsample_bytree': 0.14417394035466868, 'colsample_bynode': 0.6968881312352572, 'subsample': 0.8439647917607301, 'min_child_samples': 57, 'reg_alpha': 0.008879799267418342, 'reg_lambda': 2.948654490862709e-07, 'min_split_gain': 0.00032791870844964906}. Best is trial 86 with value: 0.42683703811949225.
# [I 2023-12-08 02:52:02,386] Trial 87 finished with value: 0.4358114233330781 and parameters: {'n_estimators': 399, 'learning_rate': 0.04207212871908037, 'num_leaves': 23, 'colsample_bytree': 0.20283049000057982, 'colsample_bynode': 0.7602965055522365, 'subsample': 0.8394212947706008, 'min_child_samples': 58, 'reg_alpha': 0.012195111182869839, 'reg_lambda': 3.193737165759907e-07, 'min_split_gain': 1.2835581854600872e-05}. Best is trial 86 with value: 0.42683703811949225.
# [I 2023-12-08 02:52:09,317] Trial 88 finished with value: 0.43397588060074355 and parameters: {'n_estimators': 490, 'learning_rate': 0.018986437158792502, 'num_leaves': 19, 'colsample_bytree': 0.16022966908358655, 'colsample_bynode': 0.699583597260697, 'subsample': 0.9738028366137369, 'min_child_samples': 26, 'reg_alpha': 0.012509319970600228, 'reg_lambda': 6.127226193581897e-08, 'min_split_gain': 0.00035372750476045026}. Best is trial 86 with value: 0.42683703811949225.
# [I 2023-12-08 02:52:14,840] Trial 89 finished with value: 0.4266241249542723 and parameters: {'n_estimators': 338, 'learning_rate': 0.03823142552491265, 'num_leaves': 25, 'colsample_bytree': 0.11704456200371535, 'colsample_bynode': 0.7411981773855513, 'subsample': 0.8573332555404777, 'min_child_samples': 27, 'reg_alpha': 0.000990350346747264, 'reg_lambda': 3.3524793330669004e-08, 'min_split_gain': 0.0006188915819100822}. Best is trial 89 with value: 0.4266241249542723.
# [I 2023-12-08 02:52:21,454] Trial 90 finished with value: 0.42580963700729785 and parameters: {'n_estimators': 430, 'learning_rate': 0.029013640727487314, 'num_leaves': 26, 'colsample_bytree': 0.12069972077066647, 'colsample_bynode': 0.7435506611455712, 'subsample': 0.7908236548749809, 'min_child_samples': 37, 'reg_alpha': 0.0013201534182897517, 'reg_lambda': 2.7187137147316233e-08, 'min_split_gain': 0.0005936877575353104}. Best is trial 90 with value: 0.42580963700729785.
# [I 2023-12-08 02:52:28,050] Trial 91 finished with value: 0.4274746861648824 and parameters: {'n_estimators': 422, 'learning_rate': 0.025185458858533728, 'num_leaves': 26, 'colsample_bytree': 0.1197246541844287, 'colsample_bynode': 0.7382010473777889, 'subsample': 0.8499835477665074, 'min_child_samples': 37, 'reg_alpha': 0.0011220390552103387, 'reg_lambda': 1.0267303508327799e-08, 'min_split_gain': 0.0006502255648633577}. Best is trial 90 with value: 0.42580963700729785.
# [I 2023-12-08 02:52:34,255] Trial 92 finished with value: 0.4279217371017783 and parameters: {'n_estimators': 414, 'learning_rate': 0.02701388900799455, 'num_leaves': 24, 'colsample_bytree': 0.10156409262833643, 'colsample_bynode': 0.7332598950774151, 'subsample': 0.793189447182739, 'min_child_samples': 47, 'reg_alpha': 0.0011020327088040174, 'reg_lambda': 1.0830960238192059e-08, 'min_split_gain': 0.0008845315688037769}. Best is trial 90 with value: 0.42580963700729785.
# [I 2023-12-08 02:52:42,365] Trial 93 finished with value: 0.42848791815434184 and parameters: {'n_estimators': 433, 'learning_rate': 0.024254433783991655, 'num_leaves': 25, 'colsample_bytree': 0.11499953628917188, 'colsample_bynode': 0.74037044151113, 'subsample': 0.7927695451640787, 'min_child_samples': 44, 'reg_alpha': 0.0011472037181119012, 'reg_lambda': 1.4771041056525465e-08, 'min_split_gain': 0.0007062491885106852}. Best is trial 90 with value: 0.42580963700729785.
# [I 2023-12-08 02:52:49,338] Trial 94 finished with value: 0.4392381479236659 and parameters: {'n_estimators': 422, 'learning_rate': 0.015565788050683815, 'num_leaves': 26, 'colsample_bytree': 0.12136070156705896, 'colsample_bynode': 0.7358555580245456, 'subsample': 0.7843607093641556, 'min_child_samples': 45, 'reg_alpha': 0.002627333522165652, 'reg_lambda': 1.1081466521508739e-08, 'min_split_gain': 0.0007743067959576531}. Best is trial 90 with value: 0.42580963700729785.
# [I 2023-12-08 02:52:56,234] Trial 95 finished with value: 0.4336676607811586 and parameters: {'n_estimators': 469, 'learning_rate': 0.030943815696498664, 'num_leaves': 22, 'colsample_bytree': 0.10045433665043658, 'colsample_bynode': 0.8051690901291655, 'subsample': 0.8093307844971797, 'min_child_samples': 35, 'reg_alpha': 0.0011832770490954817, 'reg_lambda': 2.950922201874284e-08, 'min_split_gain': 0.0005567774012234231}. Best is trial 90 with value: 0.42580963700729785.
# [I 2023-12-08 02:53:02,727] Trial 96 finished with value: 0.42850102516193067 and parameters: {'n_estimators': 422, 'learning_rate': 0.02511641201653301, 'num_leaves': 25, 'colsample_bytree': 0.11929669499019487, 'colsample_bynode': 0.7458828084320154, 'subsample': 0.85109461607271, 'min_child_samples': 52, 'reg_alpha': 0.001474118554115512, 'reg_lambda': 1.610213416224715e-08, 'min_split_gain': 0.0007192344472617394}. Best is trial 90 with value: 0.42580963700729785.
# [I 2023-12-08 02:53:09,889] Trial 97 finished with value: 0.43482253101117346 and parameters: {'n_estimators': 438, 'learning_rate': 0.025253576883558424, 'num_leaves': 24, 'colsample_bytree': 0.10045339951142512, 'colsample_bynode': 0.7706469293523502, 'subsample': 0.8475731442860504, 'min_child_samples': 52, 'reg_alpha': 0.001523068478599749, 'reg_lambda': 1.436934212612117e-08, 'min_split_gain': 0.0010360789845948908}. Best is trial 90 with value: 0.42580963700729785.
# [I 2023-12-08 02:53:17,730] Trial 98 finished with value: 0.44146978370961254 and parameters: {'n_estimators': 377, 'learning_rate': 0.017691059523414075, 'num_leaves': 27, 'colsample_bytree': 0.1449387971117841, 'colsample_bynode': 0.8277615250166588, 'subsample': 0.7907179036070606, 'min_child_samples': 44, 'reg_alpha': 0.0019060227895701537, 'reg_lambda': 1.03780200247609e-08, 'min_split_gain': 0.0013886207307913091}. Best is trial 90 with value: 0.42580963700729785.
# [I 2023-12-08 02:53:25,327] Trial 99 finished with value: 0.4348930544004387 and parameters: {'n_estimators': 501, 'learning_rate': 0.033996935776547346, 'num_leaves': 21, 'colsample_bytree': 0.11433531044929417, 'colsample_bynode': 0.7593508146634368, 'subsample': 0.8321349376108663, 'min_child_samples': 62, 'reg_alpha': 0.00400601879635372, 'reg_lambda': 3.978678748020624e-08, 'min_split_gain': 0.0004083790551122338}. Best is trial 90 with value: 0.42580963700729785.
# ['lgbm_survival.pkl']

# %%
results = study.trials_dataframe(attrs=('number','value', 'duration', 'params'))
results = results.rename(columns={'value':'log_loss'})
results['duration'] = results['duration']/np.timedelta64(1, 's')
results = results.sort_values(by='log_loss',ascending=True)
results.to_csv('cv_logloss_history.csv',index=False)
# print the top 10 results
results.head(10)
# Out:
#     number  log_loss  duration  params_colsample_bynode  \
# 90      90  0.425810  6.611059                 0.743551
# 89      89  0.426624  5.520467                 0.741198
# 86      86  0.426837  5.867023                 0.696888
# 91      91  0.427475  6.593880                 0.738201
# 74      74  0.427591  4.052805                 0.690906
# 92      92  0.427922  6.202212                 0.733260
# 93      93  0.428488  8.108106                 0.740370
# 96      96  0.428501  6.490552                 0.745883
# 73      73  0.428934  4.487483                 0.716519
# 72      72  0.429732  4.395064                 0.726880
#
#     params_colsample_bytree  params_learning_rate  params_min_child_samples  \
# 90                 0.120700              0.029014                        37
# 89                 0.117045              0.038231                        27
# 86                 0.144174              0.042297                        57
# 91                 0.119725              0.025185                        37
# 74                 0.137705              0.055770                        37
# 92                 0.101564              0.027014                        47
# 93                 0.115000              0.024254                        44
# 96                 0.119297              0.025116                        52
# 73                 0.137316              0.052086                        31
# 72                 0.123715              0.053123                        31
#
#     params_min_split_gain  params_n_estimators  params_num_leaves  \
# 90               0.000594                  430                 26
# 89               0.000619                  338                 25
# 86               0.000328                  401                 24
# 91               0.000650                  422                 26
# 74               0.000073                  368                 14
# 92               0.000885                  414                 24
# 93               0.000706                  433                 25
# 96               0.000719                  422                 25
# 73               0.000205                  406                 14
# 72               0.000167                  399                 15
#
#     params_reg_alpha  params_reg_lambda  params_subsample
# 90          0.001320       2.718714e-08          0.790824
# 89          0.000990       3.352479e-08          0.857333
# 86          0.008880       2.948654e-07          0.843965
# 91          0.001122       1.026730e-08          0.849984
# 74          0.000769       2.383257e-08          0.858710
# 92          0.001102       1.083096e-08          0.793189
# 93          0.001147       1.477104e-08          0.792770
# 96          0.001474       1.610213e-08          0.851095
# 73          0.001110       2.442790e-08          0.910975
# 72          0.000902       2.439993e-08          0.904087

# %% [markdown]
# ## Final model

# %%
model = fit_model(X, y, study.best_params, n_jobs=4)
model.booster_.save_model(
    filename='lgbm_survival.txt',importance_type='gain'
)

# %%
# %%time
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)
# Out:
# CPU times: user 38.3 s, sys: 27.4 ms, total: 38.3 s
# Wall time: 10.5 s

# %% [markdown]
# In the SHAP summary plot, we plot a horizontal bar plot of the absolute SHAP value for each feature averaged across the observations. Features with longer bars have a higher influence on the model's output for the specific class. Since we have 3 classes here, we will see 3 stacked bars for each feature. The features are ordered according to the cumulative length of the 3 bars.
#
# Let's look at the top 3 features from the plot below.
#
# 1. `Bilirubin` is very important for predicting all three classes.
# 2. `N_Days` is fairly important for predicting all three classes.
# 3. `Age` is fairly important for predicting class `CL`.
#
# Notice that the binary features aren't very important.
#
#
# **Note**: The SHAP scores were generated for a model trained after preliminary hyperparameter tuning. The observations might change in the final output run.

# %%
# Average of SHAP value magnitudes across the dataset
shap.summary_plot(
    shap_values, X, plot_type="bar",
    class_names = le.classes_,
    plot_size = (10,6)
)

# %% [markdown]
# In the cell below, we show the SHAP values separately by class. We only show the top 8 features.

# %%
avg_shap_class = [
    pd.Series(
        np.abs(shap_values[i]).mean(0),
        index = X.columns.tolist()
    ).sort_values(ascending=True) for i in range(3)
]

fig, axs = plt.subplots(1, 3, figsize=(15,4), dpi=150)
for i in range(3):
    _ = avg_shap_class[i].iloc[-8:].plot(kind='barh', ax=axs[i])
    _ = axs[i].set_title(f'Class: {le.classes_[i]}')
    
fig.tight_layout()

# %% [markdown]
# ## Test predictions

# %%
# prepare test data
test = test.drop(high_mode_per.index.tolist(), axis=1)

# binaryize labels
for col, pos_label in pos_labels.items():
    test[col] = 1 * (test[col] == pos_label)

# %%
submission = pd.DataFrame(
    model.predict_proba(test),
    columns = [f'Status_{label}' for label in le.classes_],
    index=test.index
).reset_index(drop=False)

submission.to_csv('submission.csv', index=False)
